# %% [markdown]
# # Lab | Flow Control

# %% [markdown]
# ## Exercise: Managing Customer Orders Optimized
#
# In the last lab, you were starting an online store that sells various products. To ensure smooth operations, you developed a program that manages customer orders and inventory.
#
# You did so without using flow control. Let's go a step further and improve this code.
#
# Follow the steps below to complete the exercise:
#
# 1. Look at your code from the lab data structures, and improve repeated code with loops.
#
# 2. Instead of asking the user to input the name of three products that a customer wants to order, do the following:
#
#     a. Prompt the user to enter the name of a product that a customer wants to order.
#
#     b. Add the product name to the "customer_orders" set.
#
#     c. Ask the user if they want to add another product (yes/no).
#
#     d. Continue the loop until the user does not want to add another product.
#
# 3. Instead of updating the inventory by subtracting 1 from the quantity of each product, only do it for  the products that were ordered (those in "customer_orders").

# %%
# welcome to EasyPeasyOrder

# 1.
products = ["t-shirt", "mug", "hat", "book", "keychain"]
inventory = {}
for item in products:
  quantity = int(input(f"what is the quantity of {item}s available in the inventory: "))
  inventory[item] = quantity
print(inventory)

customer_orders = set ()
count_order = 0
for item in range(0, 3):
  order_3 = (input(f"From {products}, please select one out of three products to order: "))
  customer_orders.add(order_3)
  count_order += 1
  if count_order < 3:
    print("Another product, please: ")
  else:
    print("Thank you for your order!")

for order in customer_orders:
  if order in products:
    inventory[order] -= 1
  else:
    print("Sorry, not available right now!")
#print(inventory)

if len(customer_orders) == 3:
  print("Client ordered 3 different items")
elif len(customer_orders) == 2:
  print("Client ordered three products, but there's a repeated item")
else:
  print("The client ordered 3 of a kind!")
print(customer_orders)

total_numb_products = customer_orders 
percentage_prod = len(customer_orders) / len(inventory)

print("Percentage of Products Ordered:", round(percentage_prod, 1),"%")

for item in products:
  inventory[item] -= 1

print(inventory)

for item in inventory.values():
  print(item)

# 2. EasyPeasyOrder
# a.
order = (input(f"From {products}, please select one product: "))
if (order not in products):
  print("Product unavailable, try again!")
else:
  print("Do you wish another")

# b., c. and d.
customer_orders = set ()
while True:
  user_input = input("would you like to add another product? yes/no  ").lower()
  customer_orders.add(order)
  if user_input == 'no':
    print("Thank you for your order!")
    break
  elif user_input == 'yes':
    order = (input(f"From {products}, please select one product: "))
    print("Nice choice, go ahead!")
  else:
    print("Sorry, could you repeat? 'yes' or 'no'?")

# 3.
print("Updated inventory after order is:")
for order, quantity in inventory.items():
  print(f"{order} {quantity}")

print("Thank you for shopping with us!")
